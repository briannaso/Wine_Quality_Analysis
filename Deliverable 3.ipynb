# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
from config import db_password

# %%
conn = psycopg2.connect(
    host="localhost",
    database="wine-quality",
    user="postgres",
    password=db_password)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/wine-quality"

# %%
engine = create_engine(db_string)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@127.0.0.1:5432/wine-quality)

# %%
df = pd.read_sql("SELECT * FROM wine_full", engine.connect())

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               6.6             0.400         0.30             5.3      0.038
# 1               6.6             0.325         0.49             7.7      0.049
# 2               6.3             0.270         0.23             2.9      0.047
# 3               6.6             0.190         0.99             1.2      0.122
# 4               6.8             0.320         0.28             4.8      0.034
# ...             ...               ...          ...             ...        ...
# 3956            6.9             0.370         0.23             9.5      0.057
# 3957            6.1             0.270         0.30            16.7      0.039
# 3958            6.2             0.250         0.54             7.0      0.046
# 3959            7.9             0.250         0.29             5.3      0.031
# 3960            5.9             0.260         0.27            18.2      0.048
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                    20.0                 125.0  0.99204  3.36       0.73
# 1                    53.0                 217.0  0.99600  3.16       0.40
# 2                    13.0                 100.0  0.99360  3.28       0.43
# 3                    45.0                 129.0  0.99360  3.09       0.31
# 4                    25.0                 100.0  0.99026  3.08       0.47
# ...                   ...                   ...      ...   ...        ...
# 3956                 54.0                 166.0  0.99568  3.23       0.42
# 3957                 49.0                 172.0  0.99985  3.40       0.45
# 3958                 58.0                 176.0  0.99454  3.19       0.70
# 3959                 33.0                 117.0  0.99180  3.06       0.32
# 3960                 52.0                 168.0  0.99930  3.35       0.44
#
#       alchohol  quality
# 0         12.6        6
# 1          9.3        5
# 2          9.8        5
# 3          8.7        6
# 4         12.4        7
# ...        ...      ...
# 3956      10.0        5
# 3957       9.4        5
# 3958      10.4        5
# 3959      11.8        7
# 3960       9.4        5
#
# [3961 rows x 12 columns]
