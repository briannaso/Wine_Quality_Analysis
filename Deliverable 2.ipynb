# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
from config import db_password

# %%
conn = psycopg2.connect(
    host="localhost",
    database="wine-quality",
    user="postgres",
    password=db_password)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/wine-quality"

# %%
engine = create_engine(db_string)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@127.0.0.1:5432/wine-quality)

# %%
df = pd.read_sql("SELECT * FROM wine_full", engine.connect())

# %%
df
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0                6.6             0.400         0.30             5.3
# 1                6.6             0.325         0.49             7.7
# 2                6.3             0.270         0.23             2.9
# 3                6.6             0.190         0.99             1.2
# 4                7.2             0.490         0.18             2.7
# ...              ...               ...          ...             ...
# 21267            6.1             0.270         0.30            16.7
# 21268            8.7             0.420         0.45             2.4
# 21269            6.2             0.250         0.54             7.0
# 21270            7.9             0.250         0.29             5.3
# 21271            5.9             0.260         0.27            18.2
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# 0          0.038                 20.0                 125.0  0.99204  3.36
# 1          0.049                 53.0                 217.0  0.99600  3.16
# 2          0.047                 13.0                 100.0  0.99360  3.28
# 3          0.122                 45.0                 129.0  0.99360  3.09
# 4          0.069                 13.0                  34.0  0.99670  3.29
# ...          ...                  ...                   ...      ...   ...
# 21267      0.039                 49.0                 172.0  0.99985  3.40
# 21268      0.072                 32.0                  59.0  0.99617  3.33
# 21269      0.046                 58.0                 176.0  0.99454  3.19
# 21270      0.031                 33.0                 117.0  0.99180  3.06
# 21271      0.048                 52.0                 168.0  0.99930  3.35
#
#        sulphates  alchohol  quality
# 0           0.73      12.6      6.0
# 1           0.40       9.3      5.0
# 2           0.43       9.8      5.0
# 3           0.31       8.7      6.0
# 4           0.48       9.2      6.0
# ...          ...       ...      ...
# 21267       0.45       9.4      NaN
# 21268       0.77      12.0      NaN
# 21269       0.70      10.4      NaN
# 21270       0.32      11.8      NaN
# 21271       0.44       9.4      NaN
#
# [21272 rows x 12 columns]
